# %%
import geopandas as gpd

# %%
merit = gpd.read_file("/import/beegfs/CMIP6/arctic-cmip6/Arctic_Rivers_Data/AK_Rivers.gpkg")
merit = merit[["COMID", "geometry"]]
merit
# Out:
#           COMID                                           geometry
# 0      81000004  LINESTRING (-155.49250 70.85500, -155.49167 70...
# 1      81000005  LINESTRING (-155.93167 70.84333, -155.93250 70...
# 2      81000006  LINESTRING (-156.10500 70.83750, -156.10583 70...
# 3      81000007  LINESTRING (-156.42833 70.85083, -156.42750 70...
# 4      81000011  LINESTRING (-156.00417 70.90750, -156.00500 70...
# ...         ...                                                ...
# 34203  82001686  LINESTRING (-141.43667 69.10417, -141.43750 69...
# 34204  82001698  LINESTRING (-143.03417 69.12250, -143.03333 69...
# 34205  82001703  LINESTRING (-141.32500 69.15333, -141.32500 69...
# 34206  82001706  LINESTRING (-142.18417 69.12250, -142.18500 69...
# 34207  82001714  LINESTRING (-142.18417 69.12250, -142.18500 69...
#
# [34208 rows x 2 columns]

# %%
merit.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
merit.to_file("/import/beegfs/CMIP6/jdpaul3/arctic_rivers_data/arctic_segments.shp")
